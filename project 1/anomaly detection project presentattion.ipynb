# %%
import os
import sys
from time import time 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from scipy.io import loadmat

# %%
from pyod.models.pca import PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging
# Out:
# C:\Users\vivek\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %%
data=loadmat('project day 1\Anamoly_detec_data\cardio')

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#          -0.28978574, -0.49329397],
#         [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#          -0.25638541, -0.49329397],
#         [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#          -0.25638541,  1.14001753],
#         ...,
#         [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#           0.24461959, -0.49329397],
#         [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#           0.14441859, -0.49329397],
#         [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#           3.58465295, -0.49329397]]),
#  'y': array([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])}

# %%
mat_file_list = ['arrhythmia.mat','cardio.mat',
                 'glass.mat','ionosphere.mat',
                 'letter.mat','lympho.mat',
                 'mnist.mat','musk.mat',
                 'optdigits.mat','pendigits.mat',
                 'pima.mat','satellite.mat',
                 'satimage-2.mat','shuttle.mat',
                 'vertebral.mat','vowels.mat','wbc.mat']

# %%
mat_file_list
# Out:
# ['arrhythmia.mat',
#  'cardio.mat',
#  'glass.mat',
#  'ionosphere.mat',
#  'letter.mat',
#  'lympho.mat',
#  'mnist.mat',
#  'musk.mat',
#  'optdigits.mat',
#  'pendigits.mat',
#  'pima.mat',
#  'satellite.mat',
#  'satimage-2.mat',
#  'shuttle.mat',
#  'vertebral.mat',
#  'vowels.mat',
#  'wbc.mat']

# %%
len(mat_file_list)
# Out:
# 17

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
data.values()
# Out:
# dict_values([b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC', '1.0', [], array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#         -0.28978574, -0.49329397],
#        [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#         -0.25638541, -0.49329397],
#        [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#         -0.25638541,  1.14001753],
#        ...,
#        [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#          0.24461959, -0.49329397],
#        [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#          0.14441859, -0.49329397],
#        [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#          3.58465295, -0.49329397]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]])])

# %%
df_columns=['Data','#Sample','#Dimensions','Outlier Perc','PCA','MCD','OCSVM','LOF','CBLOF','KNN','HBOS','ABOD','IFOREST','FEATUREBAGGING']

# %% [markdown]
# 1-creating empty dataframes
# ->ROC dataframe to record all ROC values performed on each dataset.
# ->Precision Dataframe to record all Precision values performed on each dataset.
# ->Execution Time Dataframe to record the time taken to prtform algorithm on each dataset, So as to find the algorithm which takes minimum amount of time and gives best accuracy.

# %%
#ROC dataset
roc_df=pd.DataFrame(columns=df_columns)
roc_df
# Out:
# Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: []

# %%
#Precision Dataframe
prn_df=pd.DataFrame(columns=df_columns)
prn_df
# Out:
# Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: []

# %%
#Execution time dataframe 
time_df=pd.DataFrame(columns=df_columns)
time_df
# Out:
# Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: []

# %%
data_1 = loadmat('project day 1\Anamoly_detec_data/vowels.mat')
data_1
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-26 08:42:13 UTC',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[ 0.58046914, -0.90253404,  0.61789919, ...,  1.60463715,
#          -0.6230598 , -0.38312549],
#         [ 0.78437493, -1.07736635,  0.6157809 , ...,  1.26023551,
#          -0.42333934, -0.2877912 ],
#         [ 0.79129238, -1.08624216,  0.66977272, ...,  1.08179729,
#          -0.26720104, -0.17220348],
#         ...,
#         [ 0.9470763 ,  0.35810832,  0.27472497, ..., -1.08832841,
#           0.3271257 ,  1.69283401],
#         [ 1.58485142,  0.69359118, -0.37568588, ..., -3.07682047,
#          -0.24109405,  1.94433536],
#         [ 2.32735022,  0.38281412,  0.77590669, ..., -0.48257003,
#          -0.59043614, -0.72199018]]),
#  'y': array([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])}

# %%
time_df=pd.DataFrame(columns=df_columns)
time_df
# Out:
# Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: []

# %% [markdown]
# *Mat files in form of Dictionary
# *in the file header,version,and gloibals are predefined classes.
# *X and Y are the variables we are going to use , Like in Ml we don't need to define the X & Y seperately.
# ->X & Y are 2D numpy arrays

# %%
# Creating random state
random_state = np.random.RandomState(42)

# Processing mat files one by one : 
for mat_file in mat_file_list:
    print("\n... Processing", mat_file, '...')
    mat = loadmat(os.path.join('project day 1\Anamoly_detec_data', mat_file))

    X = mat['X']
    y = mat['y'].ravel()  #ravel() function converts 2D to 1D
    
    # Counting Outlier :
    
    # Counts the number of non-zero values in the array y and divide by length of y : It gives outlier in fraction
    outliers_fraction = np.count_nonzero(y) / len(y)
    
    # Calculating Outlier percentage
    outliers_percentage = round(outliers_fraction * 100, ndigits=4)

    # Construct containers for saving results
    roc_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    prn_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    time_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]

    # Spliting Data into : 60% data for training and 40% for testing
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=random_state)
    
    # standardizing data for processing
    X_train_norm, X_test_norm = standardizer(X_train, X_test)

    # Applying all the algorithms and storing thier result in a dictionary format:
    classifiers = {'Angle-based Outlier Detector (ABOD)': ABOD(contamination=outliers_fraction),
                   
                   'Cluster-based Local Outlier Factor': CBLOF(contamination=outliers_fraction, check_estimator=False,
                                                               random_state=random_state),
                   
                   'Feature Bagging': FeatureBagging(contamination=outliers_fraction, random_state=random_state),
                   
                   'Histogram-base Outlier Detection (HBOS)': HBOS(contamination=outliers_fraction),
                   
                   'Isolation Forest': IForest(contamination=outliers_fraction, random_state=random_state),
                   
                   'K Nearest Neighbors (KNN)': KNN(contamination=outliers_fraction),
                   
                   'Local Outlier Factor (LOF)': LOF(contamination=outliers_fraction),
                   
                   'Minimum Covariance Determinant (MCD)': MCD(contamination=outliers_fraction, random_state=random_state),
                   
                   'One-class SVM (OCSVM)': OCSVM(contamination=outliers_fraction),
                   
                   'Principal Component Analysis (PCA)': PCA(contamination=outliers_fraction, random_state=random_state),
   }


    # Calculating Time taken for each algorithm
    for clf_name, clf in classifiers.items():
        # Initialize the start time 
        t0 = time() 
        
        # Fit( Train )the data
        clf.fit(X_train_norm) 
        
        # Predicting Value on Xtest
        test_scores = clf.decision_function(X_test_norm)  
        
        # Final Time
        t1 = time()   
        
        # Total time duration : t1 - t0
        duration = round(t1 - t0, ndigits=4) 
        
        # Append duration in time list
        time_list.append(duration)

        #Calculating roc and precision value of the algorithm
        roc = round(roc_auc_score(y_test, test_scores), ndigits=4)
        prn = round(precision_n_scores(y_test, test_scores), ndigits=4)

        # Print the roc , precision and executing time 
        print('{clf_name} ROC:{roc}, precision @ rank n:{prn}, '
              'execution time: {duration}s'.format(clf_name=clf_name, roc=roc, prn=prn, duration=duration))

        # Append roc and precision value to their respective list
        roc_list.append(roc)
        prn_list.append(prn)

    temp_df = pd.DataFrame(time_list).transpose()
    temp_df.columns = df_columns
    time_df = pd.concat([time_df, temp_df], axis=0)

    temp_df = pd.DataFrame(roc_list).transpose()
    temp_df.columns = df_columns
    roc_df = pd.concat([roc_df, temp_df], axis=0)
    
    temp_df = pd.DataFrame(prn_list).transpose()
    temp_df.columns = df_columns
    prn_df = pd.concat([prn_df, temp_df], axis=0)
# Out:
# ... Processing arrhythmia.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7687, precision @ rank n:0.3571, execution time: 0.3137s
# Cluster-based Local Outlier Factor ROC:0.7684, precision @ rank n:0.4643, execution time: 0.1926s
# Feature Bagging ROC:0.7799, precision @ rank n:0.5, execution time: 0.7601s
# Histogram-base Outlier Detection (HBOS) ROC:0.8511, precision @ rank n:0.5714, execution time: 0.1026s
# Isolation Forest ROC:0.8527, precision @ rank n:0.5714, execution time: 0.6315s
# K Nearest Neighbors (KNN) ROC:0.782, precision @ rank n:0.5, execution time: 0.1123s
# Local Outlier Factor (LOF) ROC:0.7787, precision @ rank n:0.4643, execution time: 0.0921s
# C:\Users\vivek\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinant (MCD) ROC:0.8228, precision @ rank n:0.4286, execution time: 1.0277s
# One-class SVM (OCSVM) ROC:0.7986, precision @ rank n:0.5, execution time: 0.0545s
# Principal Component Analysis (PCA) ROC:0.7997, precision @ rank n:0.5, execution time: 0.0761s
#
# ... Processing cardio.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5763, precision @ rank n:0.1875, execution time: 0.5664s
# Cluster-based Local Outlier Factor ROC:0.8221, precision @ rank n:0.4844, execution time: 0.2697s
# Feature Bagging ROC:0.4879, precision @ rank n:0.1406, execution time: 1.0828s
# Histogram-base Outlier Detection (HBOS) ROC:0.8453, precision @ rank n:0.4688, execution time: 0.01s
# Isolation Forest ROC:0.9414, precision @ rank n:0.5, execution time: 0.5764s
# K Nearest Neighbors (KNN) ROC:0.6959, precision @ rank n:0.2812, execution time: 0.2112s
# Local Outlier Factor (LOF) ROC:0.4715, precision @ rank n:0.125, execution time: 0.1346s
# C:\Users\vivek\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# C:\Users\vivek\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.076751858648862 > -250.756822706501453). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# Minimum Covariance Determinant (MCD) ROC:0.8778, precision @ rank n:0.3906, execution time: 0.8366s
# One-class SVM (OCSVM) ROC:0.9507, precision @ rank n:0.5938, execution time: 0.1176s
# Principal Component Analysis (PCA) ROC:0.9638, precision @ rank n:0.6875, execution time: 0.0055s
#
# ... Processing glass.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7104, precision @ rank n:0.25, execution time: 0.0756s
# Cluster-based Local Outlier Factor ROC:0.8506, precision @ rank n:0.25, execution time: 0.0901s
# Feature Bagging ROC:0.7043, precision @ rank n:0.25, execution time: 0.0485s
# Histogram-base Outlier Detection (HBOS) ROC:0.6524, precision @ rank n:0.0, execution time: 0.004s
# Isolation Forest ROC:0.7195, precision @ rank n:0.25, execution time: 0.4098s
# K Nearest Neighbors (KNN) ROC:0.7805, precision @ rank n:0.25, execution time: 0.0125s
# Local Outlier Factor (LOF) ROC:0.7774, precision @ rank n:0.25, execution time: 0.004s
# Minimum Covariance Determinant (MCD) ROC:0.7165, precision @ rank n:0.0, execution time: 0.0501s
# One-class SVM (OCSVM) ROC:0.6189, precision @ rank n:0.25, execution time: 0.0022s
# Principal Component Analysis (PCA) ROC:0.622, precision @ rank n:0.25, execution time: 0.0025s
#
# ... Processing ionosphere.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9004, precision @ rank n:0.8214, execution time: 0.1131s
# Cluster-based Local Outlier Factor ROC:0.8952, precision @ rank n:0.8036, execution time: 0.0831s
# Feature Bagging ROC:0.8933, precision @ rank n:0.75, execution time: 0.0926s
# Histogram-base Outlier Detection (HBOS) ROC:0.5195, precision @ rank n:0.3393, execution time: 0.015s
# Isolation Forest ROC:0.8309, precision @ rank n:0.6607, execution time: 0.4549s
# K Nearest Neighbors (KNN) ROC:0.9134, precision @ rank n:0.8393, execution time: 0.023s
# Local Outlier Factor (LOF) ROC:0.8989, precision @ rank n:0.75, execution time: 0.0085s
# Minimum Covariance Determinant (MCD) ROC:0.9399, precision @ rank n:0.8571, execution time: 0.1161s
# One-class SVM (OCSVM) ROC:0.8372, precision @ rank n:0.7143, execution time: 0.0105s
# Principal Component Analysis (PCA) ROC:0.7971, precision @ rank n:0.5893, execution time: 0.004s
#
# ... Processing letter.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8465, precision @ rank n:0.275, execution time: 0.6915s
# Cluster-based Local Outlier Factor ROC:0.7423, precision @ rank n:0.175, execution time: 0.2753s
# Feature Bagging ROC:0.866, precision @ rank n:0.4, execution time: 0.9897s
# Histogram-base Outlier Detection (HBOS) ROC:0.5728, precision @ rank n:0.125, execution time: 0.014s
# Isolation Forest ROC:0.5778, precision @ rank n:0.05, execution time: 0.566s
# K Nearest Neighbors (KNN) ROC:0.845, precision @ rank n:0.3, execution time: 0.1746s
# Local Outlier Factor (LOF) ROC:0.8409, precision @ rank n:0.325, execution time: 0.1226s
# Minimum Covariance Determinant (MCD) ROC:0.7499, precision @ rank n:0.075, execution time: 1.7933s
# One-class SVM (OCSVM) ROC:0.5744, precision @ rank n:0.1, execution time: 0.1171s
# Principal Component Analysis (PCA) ROC:0.48, precision @ rank n:0.05, execution time: 0.0085s
#
# ... Processing lympho.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9382, precision @ rank n:0.4, execution time: 0.0655s
# Cluster-based Local Outlier Factor ROC:0.9709, precision @ rank n:0.6, execution time: 0.069s
# Feature Bagging ROC:0.9673, precision @ rank n:0.6, execution time: 0.0445s
# Histogram-base Outlier Detection (HBOS) ROC:0.9964, precision @ rank n:0.8, execution time: 0.0065s
# Isolation Forest ROC:0.9855, precision @ rank n:0.6, execution time: 0.4108s
# K Nearest Neighbors (KNN) ROC:0.9636, precision @ rank n:0.6, execution time: 0.009s
# Local Outlier Factor (LOF) ROC:0.9636, precision @ rank n:0.6, execution time: 0.0035s
# Minimum Covariance Determinant (MCD) ROC:0.9164, precision @ rank n:0.6, execution time: 0.0516s
# One-class SVM (OCSVM) ROC:0.9636, precision @ rank n:0.6, execution time: 0.002s
# Principal Component Analysis (PCA) ROC:0.9818, precision @ rank n:0.8, execution time: 0.002s
#
# ... Processing mnist.mat ...
# C:\Users\vivek\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-303.881944356529402 > -525.830836350540153). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\vivek\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-304.021763033307082 > -523.143378896311901). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\vivek\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-338.921775030610604 > -381.672782741425522). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# Angle-based Outlier Detector (ABOD) ROC:0.7813, precision @ rank n:0.3562, execution time: 9.0673s
# Cluster-based Local Outlier Factor ROC:0.8447, precision @ rank n:0.4007, execution time: 1.8523s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-d8c7e54c1bbd> in <module>
#      62
#      63         # Predicting Value on Xtest
# ---> 64         test_scores = clf.decision_function(X_test_norm)
#      65
#      66         # Final Time
#
# ~\anaconda3\lib\site-packages\pyod\models\feature_bagging.py in decision_function(self, X)
#     339         # # Reduce
#     340         # all_pred_scores = np.concatenate(all_pred_scores, axis=1)
# --> 341         all_pred_scores = self._predict_decision_scores(X)
#     342
#     343         if self.combination == 'average':
#
# ~\anaconda3\lib\site-packages\pyod\models\feature_bagging.py in _predict_decision_scores(self, X)
#     351             features = self.estimators_features_[i]
#     352             all_pred_scores[:, i] = self.estimators_[i].decision_function(
# --> 353                 X[:, features])
#     354         return all_pred_scores
#     355
#
# ~\anaconda3\lib\site-packages\pyod\models\lof.py in decision_function(self, X)
#     203         # noinspection PyProtectedMember
#     204         if _get_sklearn_version() > 19:
# --> 205             return invert_order(self.detector_._score_samples(X))
#     206         else:
#     207             return invert_order(self.detector_._decision_function(X))
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_lof.py in _score_samples(self, X)
#     470
#     471         distances_X, neighbors_indices_X = (
# --> 472             self.kneighbors(X, n_neighbors=self.n_neighbors_))
#     473         X_lrd = self._local_reachability_density(distances_X,
#     474                                                  neighbors_indices_X)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     661                 delayed_query(
#     662                     self._tree, X[s], n_neighbors, return_distance)
# --> 663                 for s in gen_even_slices(X.shape[0], n_jobs)
#     664             )
#     665         else:
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     488     under PyPy.
#     489     """
# --> 490     return tree.query(*args, **kwargs)
#     491
#     492
#
# KeyboardInterrupt:

# %%
roc_df
# Out:
#          Data #Sample #Dimensions Outlier Perc     PCA     MCD   OCSVM  \
# 0  arrhythmia     452         274      14.6018  0.7687  0.7684  0.7799
# 0      cardio    1831          21       9.6122  0.5763  0.8221  0.4879
# 0       glass     214           9       4.2056  0.7104  0.8506  0.7043
# 0  ionosphere     351          33      35.8974  0.9004  0.8952  0.8933
# 0      letter    1600          32         6.25  0.8465  0.7423   0.866
# 0      lympho     148          18       4.0541  0.9382  0.9709  0.9673
# 0       mnist    7603         100       9.2069  0.7813  0.8447  0.7259
# 0        musk    3062         166       3.1679  0.0809       1  0.5228
# 0  arrhythmia     452         274      14.6018  0.7687  0.7684  0.7799
# 0      cardio    1831          21       9.6122  0.5763  0.8221  0.4879
# 0       glass     214           9       4.2056  0.7104  0.8506  0.7043
# 0  ionosphere     351          33      35.8974  0.9004  0.8952  0.8933
# 0      letter    1600          32         6.25  0.8465  0.7423   0.866
# 0      lympho     148          18       4.0541  0.9382  0.9709  0.9673
#
#       LOF   CBLOF     KNN    HBOS    ABOD IFOREST FEATUREBAGGING
# 0  0.8511  0.8527   0.782  0.7787  0.8228  0.7986         0.7997
# 0  0.8453  0.9414  0.6959  0.4715  0.8778  0.9507         0.9638
# 0  0.6524  0.7195  0.7805  0.7774  0.7165  0.6189          0.622
# 0  0.5195  0.8309  0.9134  0.8989  0.9399  0.8372         0.7971
# 0  0.5728  0.5778   0.845  0.8409  0.7499  0.5744           0.48
# 0  0.9964  0.9855  0.9636  0.9636  0.9164  0.9636         0.9818
# 0  0.5675  0.7801  0.8409  0.7085   0.863  0.8417         0.8396
# 0  0.9999  0.9996  0.7348  0.5323       1       1              1
# 0  0.8511  0.8527   0.782  0.7787  0.8228  0.7986         0.7997
# 0  0.8453  0.9414  0.6959  0.4715  0.8778  0.9507         0.9638
# 0  0.6524  0.7195  0.7805  0.7774  0.7165  0.6189          0.622
# 0  0.5195  0.8309  0.9134  0.8989  0.9399  0.8372         0.7971
# 0  0.5728  0.5778   0.845  0.8409  0.7499  0.5744           0.48
# 0  0.9964  0.9855  0.9636  0.9636  0.9164  0.9636         0.9818

# %%
prn_df
# Out:
#          Data #Sample #Dimensions Outlier Perc     PCA     MCD   OCSVM  \
# 0  arrhythmia     452         274      14.6018  0.3571  0.4643     0.5
# 0      cardio    1831          21       9.6122  0.1875  0.4844  0.1406
# 0       glass     214           9       4.2056    0.25    0.25    0.25
# 0  ionosphere     351          33      35.8974  0.8214  0.8036    0.75
# 0      letter    1600          32         6.25   0.275   0.175     0.4
# 0      lympho     148          18       4.0541     0.4     0.6     0.6
# 0       mnist    7603         100       9.2069  0.3562  0.4007  0.3664
# 0        musk    3062         166       3.1679  0.0333       1  0.1667
# 0  arrhythmia     452         274      14.6018  0.3571  0.4643     0.5
# 0      cardio    1831          21       9.6122  0.1875  0.4844  0.1406
# 0       glass     214           9       4.2056    0.25    0.25    0.25
# 0  ionosphere     351          33      35.8974  0.8214  0.8036    0.75
# 0      letter    1600          32         6.25   0.275   0.175     0.4
# 0      lympho     148          18       4.0541     0.4     0.6     0.6
#
#       LOF   CBLOF     KNN    HBOS    ABOD IFOREST FEATUREBAGGING
# 0  0.5714  0.5714     0.5  0.4643  0.4286     0.5            0.5
# 0  0.4688     0.5  0.2812   0.125  0.3906  0.5938         0.6875
# 0       0    0.25    0.25    0.25       0    0.25           0.25
# 0  0.3393  0.6607  0.8393    0.75  0.8571  0.7143         0.5893
# 0   0.125    0.05     0.3   0.325   0.075     0.1           0.05
# 0     0.8     0.6     0.6     0.6     0.6     0.6            0.8
# 0  0.1199  0.2979  0.4144   0.339  0.3973  0.3801         0.3767
# 0  0.9667  0.9333  0.2333  0.1333  0.9667       1              1
# 0  0.5714  0.5714     0.5  0.4643  0.4286     0.5            0.5
# 0  0.4688     0.5  0.2812   0.125  0.3906  0.5938         0.6875
# 0       0    0.25    0.25    0.25       0    0.25           0.25
# 0  0.3393  0.6607  0.8393    0.75  0.8571  0.7143         0.5893
# 0   0.125    0.05     0.3   0.325   0.075     0.1           0.05
# 0     0.8     0.6     0.6     0.6     0.6     0.6            0.8

# %%
time_df
# Out:
#          Data #Sample #Dimensions Outlier Perc      PCA     MCD    OCSVM  \
# 0  arrhythmia     452         274      14.6018  34.2845  4.9102   0.8986
# 0      cardio    1831          21       9.6122   0.5999  0.2702   1.2099
# 0       glass     214           9       4.2056   0.1081  0.0951    0.056
# 0  ionosphere     351          33      35.8974   0.1381  0.0831   0.0941
# 0      letter    1600          32         6.25    0.506  0.1791   0.9177
# 0      lympho     148          18       4.0541   0.0425   0.069   0.0565
# 0       mnist    7603         100       9.2069   8.6953  1.9224  61.6535
# 0        musk    3062         166       3.1679   3.0512  0.6159  16.8122
# 0  arrhythmia     452         274      14.6018   0.3137  0.1926   0.7601
# 0      cardio    1831          21       9.6122   0.5664  0.2697   1.0828
# 0       glass     214           9       4.2056   0.0756  0.0901   0.0485
# 0  ionosphere     351          33      35.8974   0.1131  0.0831   0.0926
# 0      letter    1600          32         6.25   0.6915  0.2753   0.9897
# 0      lympho     148          18       4.0541   0.0655   0.069   0.0445
#
#       LOF   CBLOF     KNN    HBOS     ABOD IFOREST FEATUREBAGGING
# 0  2.9473  0.8159  0.1514    0.09   2.8851  0.1011         0.3147
# 0  0.0215  0.8911  0.2151  0.1301   0.8992  0.1056         0.0665
# 0   0.004  0.5414   0.018   0.005   0.1151   0.003         0.0356
# 0  0.0125  0.4334  0.0245    0.01   0.1036    0.01          0.062
# 0  0.0135  0.5419  0.1781  0.1074   1.7738  0.1181          0.011
# 0  0.0075  0.3968   0.009  0.0045   0.0548  0.0015         0.0025
# 0   0.074  3.6186  8.4973  7.6455   5.0086  5.2013         0.2605
# 0  0.0871  2.1527  2.2276  1.9629  23.9386  1.8113          0.226
# 0  0.1026  0.6315  0.1123  0.0921   1.0277  0.0545         0.0761
# 0    0.01  0.5764  0.2112  0.1346   0.8366  0.1176         0.0055
# 0   0.004  0.4098  0.0125   0.004   0.0501  0.0022         0.0025
# 0   0.015  0.4549   0.023  0.0085   0.1161  0.0105          0.004
# 0   0.014   0.566  0.1746  0.1226   1.7933  0.1171         0.0085
# 0  0.0065  0.4108   0.009  0.0035   0.0516   0.002          0.002
